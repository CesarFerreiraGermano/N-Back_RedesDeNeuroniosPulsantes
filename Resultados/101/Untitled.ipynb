# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_010 = pd.read_csv('010.txt', sep=" ", header=None)
df_012 = pd.read_csv('012.txt', sep=" ", header=None)
df_013 = pd.read_csv('013.txt', sep=" ", header=None)

df_020 = pd.read_csv('020.txt', sep=" ", header=None)
df_021 = pd.read_csv('021.txt', sep=" ", header=None)
df_023 = pd.read_csv('023.txt', sep=" ", header=None)

df_030 = pd.read_csv('030.txt', sep=" ", header=None)
df_031 = pd.read_csv('031.txt', sep=" ", header=None)
df_032 = pd.read_csv('032.txt', sep=" ", header=None)

df_101 = pd.read_csv('101.txt', sep=" ", header=None)
df_102 = pd.read_csv('102.txt', sep=" ", header=None)
df_103 = pd.read_csv('103.txt', sep=" ", header=None)

df_120 = pd.read_csv('120.txt', sep=" ", header=None)
df_121 = pd.read_csv('121.txt', sep=" ", header=None)
df_123 = pd.read_csv('123.txt', sep=" ", header=None)

df_130 = pd.read_csv('130.txt', sep=" ", header=None)
df_131 = pd.read_csv('131.txt', sep=" ", header=None)
df_132 = pd.read_csv('132.txt', sep=" ", header=None)

df_201 = pd.read_csv('201.txt', sep=" ", header=None)
df_202 = pd.read_csv('202.txt', sep=" ", header=None)
df_203 = pd.read_csv('203.txt', sep=" ", header=None)

df_210 = pd.read_csv('210.txt', sep=" ", header=None)
df_212 = pd.read_csv('212.txt', sep=" ", header=None)
df_213 = pd.read_csv('213.txt', sep=" ", header=None)

df_230 = pd.read_csv('230.txt', sep=" ", header=None)
df_231 = pd.read_csv('231.txt', sep=" ", header=None)
df_232 = pd.read_csv('232.txt', sep=" ", header=None)

df_301 = pd.read_csv('301.txt', sep=" ", header=None)
df_302 = pd.read_csv('302.txt', sep=" ", header=None)
df_303 = pd.read_csv('303.txt', sep=" ", header=None)

df_310 = pd.read_csv('310.txt', sep=" ", header=None)
df_312 = pd.read_csv('312.txt', sep=" ", header=None)
df_313 = pd.read_csv('313.txt', sep=" ", header=None)

df_320 = pd.read_csv('320.txt', sep=" ", header=None)
df_321 = pd.read_csv('321.txt', sep=" ", header=None)
df_323 = pd.read_csv('323.txt', sep=" ", header=None)

df_0101 = pd.read_csv('4_0101.txt', sep=" ", header=None)
df_0102 = pd.read_csv('4_0102.txt', sep=" ", header=None)
df_0103 = pd.read_csv('4_0103.txt', sep=" ", header=None)

# %%
df_010.plot(x=0,y=13,legend=None)
plt.title('010: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('010.png')

df_012.plot(x=0,y=13,legend=None)
plt.title('012: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('012.png')

df_013.plot(x=0,y=13,legend=None)
plt.title('013: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('013.png')

# %%
df_020.plot(x=0,y=13,legend=None)
plt.title('020: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('020.png')

df_021.plot(x=0,y=13,legend=None)
plt.title('021: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('021.png')

df_023.plot(x=0,y=13,legend=None)
plt.title('023: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('023.png')

# %%
df_030.plot(x=0,y=13,legend=None)
plt.title('030: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('030.png')

df_031.plot(x=0,y=13,legend=None)
plt.title('031: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('031.png')

df_032.plot(x=0,y=13,legend=None)
plt.title('032: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('032.png')

# %%
df_101.plot(x=0,y=13,legend=None)
plt.title('101: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('101.png')

df_102.plot(x=0,y=13,legend=None)
plt.title('102: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('102.png')

df_103.plot(x=0,y=13,legend=None)
plt.title('103: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('103.png')

# %%
df_120.plot(x=0,y=13,legend=None)
plt.title('120: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('120.png')

df_121.plot(x=0,y=13,legend=None)
plt.title('121: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('121.png')

df_123.plot(x=0,y=13,legend=None)
plt.title('123: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('123.png')

# %%
df_130.plot(x=0,y=13,legend=None)
plt.title('130: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('130.png')

df_131.plot(x=0,y=13,legend=None)
plt.title('131: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('131.png')

df_132.plot(x=0,y=13,legend=None)
plt.title('132: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('132.png')

# %%
df_201.plot(x=0,y=13,legend=None)
plt.title('201: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('201.png')

df_202.plot(x=0,y=13,legend=None)
plt.title('202: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('202.png')

df_203.plot(x=0,y=13,legend=None)
plt.title('203: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('203.png')

# %%
df_210.plot(x=0,y=13,legend=None)
plt.title('210: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('210.png')

df_212.plot(x=0,y=13,legend=None)
plt.title('212: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('212.png')

df_213.plot(x=0,y=13,legend=None)
plt.title('213: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('213.png')

# %%
df_230.plot(x=0,y=13,legend=None)
plt.title('230: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('230.png')

df_231.plot(x=0,y=13,legend=None)
plt.title('231: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('231.png')

df_232.plot(x=0,y=13,legend=None)
plt.title('232: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('232.png')

# %%
df_301.plot(x=0,y=13,legend=None)
plt.title('301: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('301.png')

df_302.plot(x=0,y=13,legend=None)
plt.title('302: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('302.png')

df_303.plot(x=0,y=13,legend=None)
plt.title('303: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('303.png')

# %%
df_310.plot(x=0,y=13,legend=None)
plt.title('310: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('310.png')

df_312.plot(x=0,y=13,legend=None)
plt.title('312: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('312.png')

df_313.plot(x=0,y=13,legend=None)
plt.title('313: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('313.png')

# %%
df_320.plot(x=0,y=13,legend=None)
plt.title('320: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('320.png')

df_321.plot(x=0,y=13,legend=None)
plt.title('321: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('321.png')

df_323.plot(x=0,y=13,legend=None)
plt.title('323: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('323.png')

# %%
df_0101.plot(x=0,y=13,legend=None)
plt.title('0101: Tempo x V durante 4 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('4_0101.png')

df_0102.plot(x=0,y=13,legend=None)
plt.title('0102: Tempo x V durante 4 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('4_0102.png')

df_0103.plot(x=0,y=13,legend=None)
plt.title('0103: Tempo x V durante 4 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('4_0103.png')

# %%
df_tempo = pd.read_csv('tempo.txt', sep=" ", header=None)

df_tempo.plot(x=0,y=13,legend=None)
plt.title('0103: Tempo x V durante 4 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,-60))
plt.savefig('teste_tempo.png')

# %%
df_tempo = pd.read_csv('101_3est_estavel.txt', sep=" ", header=None)

df_tempo.plot(x=0,y=13,legend=None)
plt.title('101: Tempo x V após estabilização')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
plt.savefig('101_3est_estavel.png')


df_tempo.plot(x=0,y=15,legend=None)
plt.title('101: Tempo x I após estabilização')
plt.xlabel('Tempo')
plt.ylabel('I')
plt.ylim((-90,40))
plt.savefig('101_3est_estavel_i.png')

# %%
df_010.plot(x=0,y=1,legend=None)
plt.title('010: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
#plt.savefig('010_u.png')

df_012.plot(x=0,y=4,legend=None)
plt.title('012: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
#plt.savefig('012_u.png')

df_013.plot(x=0,y=7,legend=None)
plt.title('013: Tempo x V durante 3 primeiras janelas')
plt.xlabel('Tempo')
plt.ylabel('V')
plt.ylim((-90,40))
#plt.savefig('013_u.png')
# Out:
# (-90, 40)
